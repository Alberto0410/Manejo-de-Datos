# %%
import re

# %%
archivo = open("ManejodeDatos9180.txt").read()
# print(archivo)

nombres = "\d+\s+[A-Za-zÁÉÍÓÚáéíóüñÑ]+\s+[A-Za-zÁÉÍÓÚáéíóüñÑ]+\s+[A-Za-zÁÉÍÓÚáéíóüñÑ]+\s+[A-Za-zÁÉÍÓÚáéíóüñÑ]+"
email = "\w\S*@.*\t"
mail = "\w\S*@\S+"
dominio = "@\S+\t"

encontrar = re.findall(nombres, archivo)
print(encontrar)
# Out:
# ['2\tNombre\tCarrera\tCorreo\tTelefono', '1\tAlemán\tGalicia\tDiego Leónardo', '2\tAmador\tGónzalez\tNoé Eusebio', '3\tAmaro\tIslas\tYamile Amalia', '4\tCabrera\tPérez\tRodrígo\tActuaría', '5\tCazares\tSolis\tAndrea Nicole', '6\tContreras\tChávez\tCitlali\tActuaría', '7\tDorantes\tBravo\tAlicia\tAplicadas', '8\tDurán\tSantiago\tRafael\tAplicadas', '9\tEnríquez\tRíos\tMichelle Guadalupe', '10\tFlores\tDelgado\tOmar Alejandro', '11\tGarcés\tGarduño\tRodrígo Tonatihu', '12\tGarcía\tAzamar\tCristopher Alejandro', '13\tGarcía\tMejía\tRandy Jes', '14\tGómez\tArteaga\tBeu Ribe', '15\tGónzalez\tGarcía\tMaricela\tActuaría', '16\tGuevara\tLegaspe\tLeslye Joseline', '18\tHérnandez\tLópez\tAlejandro\tActuaría', '19\tJuárez\tDiosdado\tUlises\tAplicadas', '20\tLerdo de Tejada\tFlores', '21\tNuñez\tVega\tAdive Alejandra', '23\tPérez\tEscartin\tMaya Aranzazu', '24\tRamírez\tCarmona\tAxel Gabriel', '25\tReséndiz\tGuerrero\tMariella Vanesa', '26\tRivera\tRamírez\tMaría Fernanda', '27\tRodríguez\tHérna
# ...

# %%
for nombre in range(len(encontrar)):
  #Borramos los espacios
  encontrar[nombre] = encontrar[nombre].replace("\t", " ")
  encontrar[nombre] = encontrar[nombre][2:]
print(encontrar)
# Out:
# ['Nombre Carrera Correo Telefono', 'Alemán Galicia Diego Leónardo', 'Amador Gónzalez Noé Eusebio', 'Amaro Islas Yamile Amalia', 'Cabrera Pérez Rodrígo Actuaría', 'Cazares Solis Andrea Nicole', 'Contreras Chávez Citlali Actuaría', 'Dorantes Bravo Alicia Aplicadas', 'Durán Santiago Rafael Aplicadas', 'Enríquez Ríos Michelle Guadalupe', ' Flores Delgado Omar Alejandro', ' Garcés Garduño Rodrígo Tonatihu', ' García Azamar Cristopher Alejandro', ' García Mejía Randy Jes', ' Gómez Arteaga Beu Ribe', ' Gónzalez García Maricela Actuaría', ' Guevara Legaspe Leslye Joseline', ' Hérnandez López Alejandro Actuaría', ' Juárez Diosdado Ulises Aplicadas', ' Lerdo de Tejada Flores', ' Nuñez Vega Adive Alejandra', ' Pérez Escartin Maya Aranzazu', ' Ramírez Carmona Axel Gabriel', ' Reséndiz Guerrero Mariella Vanesa', ' Rivera Ramírez María Fernanda', ' Rodríguez Hérnandez Ricardo Aplicadas', ' Rodríguez Rojas Aarón Israel', ' Rodríguez Vega Octavio Matemáticas', ' Salinas Avelino Elizabeth Actuaría', 
# ...
